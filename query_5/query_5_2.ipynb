# %%
# %%configure -f
# {
#     "conf":{
#         "spark.executor.instances": "4",
#         "spark.executor.memory": "4g",
#         "spark.executor.cores": "2"
#     }
# }
# Out:
# Current session configs: <tt>{'conf': {'spark.sql.catalog.spark_catalog.type': 'hive', 'spark.executor.instances': '4', 'spark.executor.memory': '4g', 'spark.executor.cores': '2'}, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>952</td><td>application_1765289937462_0945</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0945/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-55.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0945_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>956</td><td>application_1765289937462_0949</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0949/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-149.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0949_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>961</td><td>application_1765289937462_0954</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0954/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-103.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0954_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>962</td><td>application_1765289937462_0955</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0955/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-48.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0955_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>967</td><td>application_1765289937462_0960</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0960/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-213.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0960_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>979</td><td>application_1765289937462_0972</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0972/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-149.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0972_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>981</td><td>application_1765289937462_0974</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0974/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-61.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0974_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>982</td><td>application_1765289937462_0975</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0975/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-131.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0975_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>984</td><td>application_1765289937462_0977</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0977/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-61.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0977_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>985</td><td>application_1765289937462_0978</td><td>pyspark</td><td>busy</td><td><a target="_blank" href ...

# %%
from sedona.spark import *
from pyspark.sql import SparkSession


from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import udf, year, avg, count, concat, lit, round, rank, col, regexp_replace, substring, corr

spark = SparkSession \
    .builder \
    .appName("query 4 execution") \
    .getOrCreate()

# Create sedona context
sedona = SedonaContext.create(spark)


crime_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", header = True, inferSchema = True)
# crime

geojson_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Census_Blocks_2020.geojson"
blocks_df = sedona.read.format("geojson") \
            .option("multiLine", "true").load(geojson_path) \
            .selectExpr("explode(features) as features") \
            .select("features.*")
# Formatting magic
flattened_df = blocks_df.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type") 
# census

median_household_income= "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_income_2021.csv"
# median_df = spark.read.csv(median_household_income, header = True, inferSchema = True)
median_df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .option("delimiter", ";") 
    .csv(median_household_income)
)
#median_household_income

# Print schema
flattened_df.printSchema()
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>986</td><td>application_1765289937462_0979</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0979/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-103.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0979_01_000002/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- BG20: string (nullable = true)
#  |-- BG20FIP_CURRENT: string (nullable = true)
#  |-- BGFIP20: string (nullable = true)
#  |-- CB20: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- CITYCOMM: string (nullable = true)
#  |-- CITYCOMM_CURRENT: string (nullable = true)
#  |-- CITY_CURRENT: string (nullable = true)
#  |-- COMM: string (nullable = true)
#  |-- COMM_CURRENT: string (nullable = true)
#  |-- COUNTY: string (nullable = true)
#  |-- CT20: string (nullable = true)
#  |-- CTCB20: string (nullable = true)
#  |-- FEAT_TYPE: string (nullable = true)
#  |-- FIP20: string (nullable = true)
#  |-- FIP_CURRENT: string (nullable = true)
#  |-- HD22: long (nullable = true)
#  |-- HD_NAME: string (nullable = true)
#  |-- HOUSING20: long (nullable = true)
#  |-- OBJECTID: long (nullable = true)
#  |-- POP20: long (nullable = true)
#  |-- SPA22: long (nullable = true)
#  |-- SPA_NAME: string (nullable = true)
#  |-- SUP21: string (nullable = true)
#  |-- SUP_LABEL: string (nullable = true)
#  |-- ShapeSTArea: double (nullable = true)
#  |-- ShapeSTLength: double (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZCTA20: string (nullable = true)
#  |-- geometry: geometry (nullable = true)

# %%
from pyspark.sql.functions import sum as _sum

#Filter data only from LA, do summations for Housing and Population
group_flattened = (
    flattened_df
    .select("COMM", "POP20", "ZCTA20", "HOUSING20" , "geometry")
    .filter(
        (col("ZCTA20") > 0) &
        (col("HOUSING20") > 0) &
        (col("POP20") > 0) &
        (col("COMM") != "")
    )
    .groupBy("COMM", "ZCTA20")
    .agg(
        _sum("POP20").alias("Total_POP"),
        _sum("HOUSING20").alias("Total_Housing"),
        ST_Union_Aggr("geometry").alias("geometry")
    )
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#join Cencus with median house income. Join key is Zip Code. Result is GDP Per Capita in every area.
joined = (
    group_flattened
    .join(median_df, group_flattened["ZCTA20"] == median_df["Zip Code"])
    .withColumn(
        "Estimated Median Income", 
        regexp_replace(col("Estimated Median Income"), "[^0-9]", "")
    )
    .withColumn(
        "ZIP_Total_Income", 
        (col("Estimated Median Income") * col("Total_Housing"))
    )
    .groupBy("COMM")
    .agg(
        _sum("Total_POP").alias("Total_COMM_Pop"),
        _sum("ZIP_Total_Income").alias("COMM_Total_Income"),
        ST_Union_Aggr("geometry").alias("geometry")
    )
    .withColumn(
        "GDP_Per_Capita",
        (col("COMM_Total_Income")/col("Total_COMM_Pop"))
    )
    .select("COMM", "GDP_Per_Capita", "geometry") 
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#keep crime data only from 2020 and 2021. Also create a geometry column according to longtitude and latitude columns.
crime_data_20_21_df = (
    crime_df
    .filter(
        (substring(col("DATE OCC"), 1, 4) == "2020") |
        (substring(col("DATE OCC"), 1, 4) == "2021") 
    )
    .select("DATE OCC", "LAT", "LON")
    .withColumn("geom", ST_Point("LON", "LAT"))
    .drop("LAT", "LON")
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#final_top_3_df.show()

final_crimes_df = (
    joined
    .join(crime_data_20_21_df, ST_Within(crime_data_20_21_df.geom, joined.geometry), "inner")
    .groupBy("COMM")
    .agg(
        count("*").alias("#")
    )
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#join Cencus with crimes per COMM. Join key is Zip Code. Result is crimes per capita in every area.
crime_joined = (
    group_flattened
    .join(final_crimes_df, on="COMM", how="inner")
    .withColumn(
        "Crimes_Per_Capita",
        (col("#")/col("Total_Pop"))
    )
    .select("COMM", "Crimes_Per_Capita") #geometry 
)

top_10 = joined.orderBy(col("GDP_Per_Capita"), ascending=False).limit(10)

bottom_10 = joined.orderBy(col("GDP_Per_Capita"), ascending=True).limit(10)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
from pyspark.sql.functions import corr
import time

#Corelation while using all areas
start1 = time.time()
corr_joined = (
    joined
    .join(crime_joined, on="COMM", how="inner") # Sort Merge Join
    .select("COMM", "GDP_Per_Capita", "Crimes_Per_Capita")
)

full_corr = corr_joined.select(
    corr("GDP_Per_Capita", "Crimes_Per_Capita")
).collect()[0][0]

print("Full data Correlation =", full_corr)
end1 = time.time()
print("Full data correlation execution time:", end1 - start1, "seconds")

#Corelation while using top10 income areas
start2 = time.time()
corr_top10 = (
    top_10
    .join(crime_joined, on="COMM", how="inner") # Broadcast Hash Join
    .select("COMM", "GDP_Per_Capita", "Crimes_Per_Capita") 
)

full_corr_top10 = corr_top10.select(
    corr("GDP_Per_Capita", "Crimes_Per_Capita")
).collect()[0][0]

print("Top 10 areas Correlation =", full_corr_top10)
end2 = time.time()
print("Top 10 areas execution time:", end2 - start2, "seconds")

#Corelation while using the bottom 10 areas
start3 = time.time()
corr_bottom10 = (
    bottom_10
    .join(crime_joined, on="COMM", how="inner") # Broadcast Hash Join
    .select("COMM", "GDP_Per_Capita", "Crimes_Per_Capita") 
)

full_corr_bot10 = corr_bottom10.select(
    corr("GDP_Per_Capita", "Crimes_Per_Capita")
).collect()[0][0]

print("Bottom 10 areas Correlation =", full_corr_bot10)
end3 = time.time()
print("Bottom 10 areas execution time:", end3 - start3, "seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Full data Correlation = 0.05699006354516789
# Full data correlation execution time: 26.067071676254272 seconds
# Top 10 areas Correlation = 0.2930302995361155
# Top 10 areas execution time: 20.86649990081787 seconds
# Bottom 10 areas Correlation = 0.17968480714580115
# Bottom 10 areas execution time: 16.88815140724182 seconds

# %%
corr_joined.explain()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [COMM#124, GDP_Per_Capita#394, Crimes_Per_Capita#497]
#    +- SortMergeJoin [COMM#124], [COMM#522], Inner
#       :- Sort [COMM#124 ASC NULLS FIRST], false, 0
#       :  +- HashAggregate(keys=[COMM#124], functions=[sum(ZIP_Total_Income#350), sum(Total_POP#299L)], schema specialized)
#       :     +- Exchange hashpartitioning(COMM#124, 1000), ENSURE_REQUIREMENTS, [plan_id=5905]
#       :        +- HashAggregate(keys=[COMM#124], functions=[partial_sum(ZIP_Total_Income#350), partial_sum(Total_POP#299L)], schema specialized)
#       :           +- Project [COMM#124, Total_POP#299L, (cast(regexp_replace(Estimated Median Income#284, [^0-9], , 1) as double) * cast(Total_Housing#301L as double)) AS ZIP_Total_Income#350]
#       :              +- BroadcastHashJoin [cast(ZCTA20#144 as int)], [Zip Code#282], Inner, BuildRight, false
#       :                 :- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[sum(POP20#136L), sum(HOUSING20#134L)], schema specialized)
#       :                 :  +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=5897]
#       :                 :     +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#       :                 :        +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#       :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#       :                 :              +- Generate explode(features#99), false, [features#107]
#       :                 :                 +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#       :                 :                    +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#       :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=5900]
#       :                    +- Filter isnotnull(Zip Code#282)
#       :                       +- FileScan csv [Zip Code#282,Estimated Median Income#284] Batched: false, DataFilters: [isnotnull(Zip Code#282)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#       +- Sort [COMM#522 ASC NULLS FIRST], false, 0
#          +- Filter bloomfilter#1792 of [bf1792 COMM#124 estimatedNumRows=255300] filtering [COMM#522]
#             :  +- GenerateBloomFilter bf1792, 255300, 0, false, false, true, true, [id=#6039]
#             :     +- OutputAdapter [COMM#124, ZCTA20#144, sum#633L, sum#635L]
#             :        +- AdaptiveSparkPlan isFinalPlan=false
#             :           +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=6036]
#             :              +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#             :                 +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#             :                    +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#             :                       +- Generate explode(features#99), false, [features#107]
#             :                          +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#             :                             +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#             +- Project [COMM#522, (cast(##430L as double) / cast(Total_Pop#299L as double)) AS Crimes_Per_Capita#497]
#                +- BroadcastHashJoin [COMM#522], [COMM#445], Inner, BuildLeft, false
#                   :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=5927]
#                   :  +- HashAggregate(keys=[COMM#522, ZCTA20#542], functions=[sum(POP20#534L)], schema specialized)
#                   :     +- Exchange hashpartitioning(COMM#522, ZCTA20#542, 1000), ENSURE_REQUIREMENTS, [plan_id=5907]
#                   :        +- HashAggregate(keys=[COMM#522, ZCTA20#542], functions=[partial_sum(POP20#534L)], schema specialized)
#                   :           +- Project [features#107.properties.COMM AS COMM#522, features#107.properties.POP20 AS POP20#534L, features#107.properties.ZCTA20 AS ZCTA20#542]
#                   :              +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                   :                 +- Generate explode(features#508), false, [features#107]
#                   :                    +- Filter ((size(features#508, true) > 0) AND isnotnull(features#508))
#                   :                       +- FileScan geojson [features#508] Batched: false, DataFilters: [(size(features#508, true) > 0), isnotnull(features#508)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                   +- HashAggregate(keys=[COMM#445], functions=[count(1)], schema specialized)
#                      +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=5924]
#                         +- HashAggregate(keys=[COMM#445], functions=[partial_count(1)], schema specialized)
#                            +- Project [COMM#445]
#                               +- RangeJoin geometry#377: geometry, geom#407: geometry, CONTAINS
#                                  :- Filter isnotnull(geometry#377)
#                                  :  +- ObjectHashAggregate(keys=[COMM#445], functions=[st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d4dd060, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :     +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=5917]
#                                  :        +- ObjectHashAggregate(keys=[COMM#445], functions=[partial_st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d4dd060, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :           +- Project [COMM#445, geometry#306]
#                                  :              +- BroadcastHashJoin [cast(ZCTA20#465 as int)], [Zip Code#511], Inner, BuildRight, false
#                                  :                 :- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@6bebf584, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :                 :  +- Exchange hashpartitioning(COMM#445, ZCTA20#465, 1000), ENSURE_REQUIREMENTS, [plan_id=5909]
#                                  :                 :     +- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[partial_st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@6bebf584, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :                 :        +- Project [features#107.properties.COMM AS COMM#445, features#107.properties.ZCTA20 AS ZCTA20#465, features#107.geometry AS geometry#110]
#                                  :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                                  :                 :              +- Generate explode(features#434), false, [features#107]
#                                  :                 :                 +- Filter ((size(features#434, true) > 0) AND isnotnull(features#434))
#                                  :                 :                    +- FileScan geojson [features#434] Batched: false, DataFilters: [(size(features#434, true) > 0), isnotnull(features#434)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                                  :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=5912]
#                                  :                    +- Filter isnotnull(Zip Code#511)
#                                  :                       +- FileScan csv [Zip Code#511] Batched: false, DataFilters: [isnotnull(Zip Code#511)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int>
#                                  +- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#407]
#                                     +- Filter (((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)) AND isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  ))
#                                        +- FileScan csv [DATE OCC#44,LAT#68,LON#69] Batched: false, DataFilters: [((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)), isnotnull( **o..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DATE OCC:string,LAT:double,LON:double>

# %%
corr_top10.explain()
corr_bottom10.explain()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [COMM#124, GDP_Per_Capita#394, Crimes_Per_Capita#497]
#    +- BroadcastHashJoin [COMM#124], [COMM#991], Inner, BuildLeft, false
#       :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6366]
#       :  +- TakeOrderedAndProject(limit=10, orderBy=[GDP_Per_Capita#394 DESC NULLS LAST], output=[COMM#124,GDP_Per_Capita#394])
#       :     +- HashAggregate(keys=[COMM#124], functions=[sum(ZIP_Total_Income#350), sum(Total_POP#299L)], schema specialized)
#       :        +- Exchange hashpartitioning(COMM#124, 1000), ENSURE_REQUIREMENTS, [plan_id=6339]
#       :           +- HashAggregate(keys=[COMM#124], functions=[partial_sum(ZIP_Total_Income#350), partial_sum(Total_POP#299L)], schema specialized)
#       :              +- Project [COMM#124, Total_POP#299L, (cast(regexp_replace(Estimated Median Income#284, [^0-9], , 1) as double) * cast(Total_Housing#301L as double)) AS ZIP_Total_Income#350]
#       :                 +- BroadcastHashJoin [cast(ZCTA20#144 as int)], [Zip Code#282], Inner, BuildRight, false
#       :                    :- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[sum(POP20#136L), sum(HOUSING20#134L)], schema specialized)
#       :                    :  +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=6331]
#       :                    :     +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#       :                    :        +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#       :                    :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#       :                    :              +- Generate explode(features#99), false, [features#107]
#       :                    :                 +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#       :                    :                    +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#       :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6334]
#       :                       +- Filter isnotnull(Zip Code#282)
#       :                          +- FileScan csv [Zip Code#282,Estimated Median Income#284] Batched: false, DataFilters: [isnotnull(Zip Code#282)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#       +- Project [COMM#991, (cast(##430L as double) / cast(Total_Pop#299L as double)) AS Crimes_Per_Capita#497]
#          +- BroadcastHashJoin [COMM#991], [COMM#445], Inner, BuildLeft, false
#             :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6362]
#             :  +- HashAggregate(keys=[COMM#991, ZCTA20#1011], functions=[sum(POP20#1003L)], schema specialized)
#             :     +- Exchange hashpartitioning(COMM#991, ZCTA20#1011, 1000), ENSURE_REQUIREMENTS, [plan_id=6342]
#             :        +- HashAggregate(keys=[COMM#991, ZCTA20#1011], functions=[partial_sum(POP20#1003L)], schema specialized)
#             :           +- Project [features#107.properties.COMM AS COMM#991, features#107.properties.POP20 AS POP20#1003L, features#107.properties.ZCTA20 AS ZCTA20#1011]
#             :              +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#             :                 +- Generate explode(features#977), false, [features#107]
#             :                    +- Filter ((size(features#977, true) > 0) AND isnotnull(features#977))
#             :                       +- FileScan geojson [features#977] Batched: false, DataFilters: [(size(features#977, true) > 0), isnotnull(features#977)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#             +- HashAggregate(keys=[COMM#445], functions=[count(1)], schema specialized)
#                +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6359]
#                   +- HashAggregate(keys=[COMM#445], functions=[partial_count(1)], schema specialized)
#                      +- Project [COMM#445]
#                         +- RangeJoin geometry#377: geometry, geom#407: geometry, CONTAINS
#                            :- Filter isnotnull(geometry#377)
#                            :  +- ObjectHashAggregate(keys=[COMM#445], functions=[st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d4dd060, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :     +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6352]
#                            :        +- ObjectHashAggregate(keys=[COMM#445], functions=[partial_st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d4dd060, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :           +- Project [COMM#445, geometry#306]
#                            :              +- BroadcastHashJoin [cast(ZCTA20#465 as int)], [Zip Code#980], Inner, BuildRight, false
#                            :                 :- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@6bebf584, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :  +- Exchange hashpartitioning(COMM#445, ZCTA20#465, 1000), ENSURE_REQUIREMENTS, [plan_id=6344]
#                            :                 :     +- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[partial_st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@6bebf584, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :        +- Project [features#107.properties.COMM AS COMM#445, features#107.properties.ZCTA20 AS ZCTA20#465, features#107.geometry AS geometry#110]
#                            :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                            :                 :              +- Generate explode(features#434), false, [features#107]
#                            :                 :                 +- Filter ((size(features#434, true) > 0) AND isnotnull(features#434))
#                            :                 :                    +- FileScan geojson [features#434] Batched: false, DataFilters: [(size(features#434, true) > 0), isnotnull(features#434)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                            :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6347]
#                            :                    +- Filter isnotnull(Zip Code#980)
#                            :                       +- FileScan csv [Zip Code#980] Batched: false, DataFilters: [isnotnull(Zip Code#980)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int>
#                            +- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#407]
#                               +- Filter (((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)) AND isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  ))
#                                  +- FileScan csv [DATE OCC#44,LAT#68,LON#69] Batched: false, DataFilters: [((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)), isnotnull( **o..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DATE OCC:string,LAT:double,LON:double>
#
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [COMM#124, GDP_Per_Capita#394, Crimes_Per_Capita#497]
#    +- BroadcastHashJoin [COMM#124], [COMM#1387], Inner, BuildLeft, false
#       :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6752]
#       :  +- TakeOrderedAndProject(limit=10, orderBy=[GDP_Per_Capita#394 ASC NULLS FIRST], output=[COMM#124,GDP_Per_Capita#394])
#       :     +- HashAggregate(keys=[COMM#124], functions=[sum(ZIP_Total_Income#350), sum(Total_POP#299L)], schema specialized)
#       :        +- Exchange hashpartitioning(COMM#124, 1000), ENSURE_REQUIREMENTS, [plan_id=6725]
#       :           +- HashAggregate(keys=[COMM#124], functions=[partial_sum(ZIP_Total_Income#350), partial_sum(Total_POP#299L)], schema specialized)
#       :              +- Project [COMM#124, Total_POP#299L, (cast(regexp_replace(Estimated Median Income#284, [^0-9], , 1) as double) * cast(Total_Housing#301L as double)) AS ZIP_Total_Income#350]
#       :                 +- BroadcastHashJoin [cast(ZCTA20#144 as int)], [Zip Code#282], Inner, BuildRight, false
#       :                    :- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[sum(POP20#136L), sum(HOUSING20#134L)], schema specialized)
#       :                    :  +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=6717]
#       :                    :     +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#       :                    :        +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#       :                    :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#       :                    :              +- Generate explode(features#99), false, [features#107]
#       :                    :                 +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#       :                    :                    +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#       :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6720]
#       :                       +- Filter isnotnull(Zip Code#282)
#       :                          +- FileScan csv [Zip Code#282,Estimated Median Income#284] Batched: false, DataFilters: [isnotnull(Zip Code#282)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#       +- Project [COMM#1387, (cast(##430L as double) / cast(Total_Pop#299L as double)) AS Crimes_Per_Capita#497]
#          +- BroadcastHashJoin [COMM#1387], [COMM#445], Inner, BuildLeft, false
#             :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6748]
#             :  +- HashAggregate(keys=[COMM#1387, ZCTA20#1407], functions=[sum(POP20#1399L)], schema specialized)
#             :     +- Exchange hashpartitioning(COMM#1387, ZCTA20#1407, 1000), ENSURE_REQUIREMENTS, [plan_id=6728]
#             :        +- HashAggregate(keys=[COMM#1387, ZCTA20#1407], functions=[partial_sum(POP20#1399L)], schema specialized)
#             :           +- Project [features#107.properties.COMM AS COMM#1387, features#107.properties.POP20 AS POP20#1399L, features#107.properties.ZCTA20 AS ZCTA20#1407]
#             :              +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#             :                 +- Generate explode(features#1373), false, [features#107]
#             :                    +- Filter ((size(features#1373, true) > 0) AND isnotnull(features#1373))
#             :                       +- FileScan geojson [features#1373] Batched: false, DataFilters: [(size(features#1373, true) > 0), isnotnull(features#1373)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#             +- HashAggregate(keys=[COMM#445], functions=[count(1)], schema specialized)
#                +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6745]
#                   +- HashAggregate(keys=[COMM#445], functions=[partial_count(1)], schema specialized)
#                      +- Project [COMM#445]
#                         +- RangeJoin geometry#377: geometry, geom#407: geometry, CONTAINS
#                            :- Filter isnotnull(geometry#377)
#                            :  +- ObjectHashAggregate(keys=[COMM#445], functions=[st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d4dd060, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :     +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6738]
#                            :        +- ObjectHashAggregate(keys=[COMM#445], functions=[partial_st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@5d4dd060, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :           +- Project [COMM#445, geometry#306]
#                            :              +- BroadcastHashJoin [cast(ZCTA20#465 as int)], [Zip Code#1376], Inner, BuildRight, false
#                            :                 :- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@6bebf584, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :  +- Exchange hashpartitioning(COMM#445, ZCTA20#465, 1000), ENSURE_REQUIREMENTS, [plan_id=6730]
#                            :                 :     +- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[partial_st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@6bebf584, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :        +- Project [features#107.properties.COMM AS COMM#445, features#107.properties.ZCTA20 AS ZCTA20#465, features#107.geometry AS geometry#110]
#                            :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                            :                 :              +- Generate explode(features#434), false, [features#107]
#                            :                 :                 +- Filter ((size(features#434, true) > 0) AND isnotnull(features#434))
#                            :                 :                    +- FileScan geojson [features#434] Batched: false, DataFilters: [(size(features#434, true) > 0), isnotnull(features#434)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                            :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6733]
#                            :                    +- Filter isnotnull(Zip Code#1376)
#                            :                       +- FileScan csv [Zip Code#1376] Batched: false, DataFilters: [isnotnull(Zip Code#1376)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int>
#                            +- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#407]
#                               +- Filter (((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)) AND isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  ))
#                                  +- FileScan csv [DATE OCC#44,LAT#68,LON#69] Batched: false, DataFilters: [((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)), isnotnull( **o..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DATE OCC:string,LAT:double,LON:double>
