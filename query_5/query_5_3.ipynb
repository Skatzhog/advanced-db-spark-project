# %%
# %%configure -f
# {
#     "conf":{
#         "spark.executor.instances": "8",
#         "spark.executor.memory": "2g",
#         "spark.executor.cores": "1"
#     }
# }
# Out:
# Current session configs: <tt>{'conf': {'spark.sql.catalog.spark_catalog.type': 'hive', 'spark.executor.instances': '8', 'spark.executor.memory': '2g', 'spark.executor.cores': '1'}, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>550</td><td>application_1765289937462_0543</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0543/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-48.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0543_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>551</td><td>application_1765289937462_0544</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0544/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-213.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0544_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>558</td><td>application_1765289937462_0551</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0551/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-207.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0551_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>568</td><td>application_1765289937462_0561</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0561/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-115.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0561_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>570</td><td>application_1765289937462_0563</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0563/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-141.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0563_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>571</td><td>application_1765289937462_0564</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0564/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-115.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0564_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>572</td><td>application_1765289937462_0565</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0565/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-207.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0565_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>573</td><td>application_1765289937462_0566</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0566/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-115.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0566_01_000001/livy">Link</a></td><td>None</td><td></td></tr><tr><td>574</td><td>application_1765289937462_0567</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0567/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-48.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0567_01_000002/livy">Link</a></td><td>None</td><td></td></tr><tr><td>575</td><td>None</td><td>pyspark</td><td>starting</td><td></td><td></td><td>None</td><td></td></tr></ ...

# %%
from sedona.spark import *
from pyspark.sql import SparkSession


from pyspark.sql.types import StructField, StructType, IntegerType, FloatType, StringType
from pyspark.sql.functions import udf, year, avg, count, concat, lit, round, rank, col, regexp_replace, substring, corr

spark = SparkSession \
    .builder \
    .appName("query 4 execution") \
    .getOrCreate()

# Create sedona context
sedona = SedonaContext.create(spark)


crime_df = spark.read.csv("s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Crime_Data/LA_Crime_Data_2020_2025.csv", header = True, inferSchema = True)
# crime

geojson_path = "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_Census_Blocks_2020.geojson"
blocks_df = sedona.read.format("geojson") \
            .option("multiLine", "true").load(geojson_path) \
            .selectExpr("explode(features) as features") \
            .select("features.*")
# Formatting magic
flattened_df = blocks_df.select( \
                [col(f"properties.{col_name}").alias(col_name) for col_name in \
                blocks_df.schema["properties"].dataType.fieldNames()] + ["geometry"]) \
            .drop("properties") \
            .drop("type") 
# census

median_household_income= "s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_income_2021.csv"
# median_df = spark.read.csv(median_household_income, header = True, inferSchema = True)
median_df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .option("delimiter", ";") 
    .csv(median_household_income)
)
#median_household_income

# Print schema
flattened_df.printSchema()
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>576</td><td>application_1765289937462_0569</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-192-168-1-63.eu-central-1.compute.internal:20888/proxy/application_1765289937462_0569/">Link</a></td><td><a target="_blank" href="http://ip-192-168-1-154.eu-central-1.compute.internal:8042/node/containerlogs/container_1765289937462_0569_01_000002/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# root
#  |-- BG20: string (nullable = true)
#  |-- BG20FIP_CURRENT: string (nullable = true)
#  |-- BGFIP20: string (nullable = true)
#  |-- CB20: string (nullable = true)
#  |-- CITY: string (nullable = true)
#  |-- CITYCOMM: string (nullable = true)
#  |-- CITYCOMM_CURRENT: string (nullable = true)
#  |-- CITY_CURRENT: string (nullable = true)
#  |-- COMM: string (nullable = true)
#  |-- COMM_CURRENT: string (nullable = true)
#  |-- COUNTY: string (nullable = true)
#  |-- CT20: string (nullable = true)
#  |-- CTCB20: string (nullable = true)
#  |-- FEAT_TYPE: string (nullable = true)
#  |-- FIP20: string (nullable = true)
#  |-- FIP_CURRENT: string (nullable = true)
#  |-- HD22: long (nullable = true)
#  |-- HD_NAME: string (nullable = true)
#  |-- HOUSING20: long (nullable = true)
#  |-- OBJECTID: long (nullable = true)
#  |-- POP20: long (nullable = true)
#  |-- SPA22: long (nullable = true)
#  |-- SPA_NAME: string (nullable = true)
#  |-- SUP21: string (nullable = true)
#  |-- SUP_LABEL: string (nullable = true)
#  |-- ShapeSTArea: double (nullable = true)
#  |-- ShapeSTLength: double (nullable = true)
#  |-- State: string (nullable = true)
#  |-- ZCTA20: string (nullable = true)
#  |-- geometry: geometry (nullable = true)

# %%
# last year
from pyspark.sql.functions import sum as _sum

#select only desired columns from 2020_Census_Blocks.geojson, filter data only from LA, keep only valid data and then do summations for Housing and Population and create geometry
group_flattened = (
    flattened_df
    .select("COMM", "POP20", "ZCTA20", "HOUSING20" , "geometry")
    .filter(
        (col("ZCTA20") > 0) &
        (col("HOUSING20") > 0) &
        (col("POP20") > 0) &
        (col("COMM") != "")
    )
    .groupBy("COMM", "ZCTA20")
    .agg(
        _sum("POP20").alias("Total_POP"),
        _sum("HOUSING20").alias("Total_Housing"),
        ST_Union_Aggr("geometry").alias("geometry")
    )
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#join Cencus with median house income. Join key is Zip Code. Result is GDP Per Capita in every area.
joined = (
    group_flattened
    .join(median_df, group_flattened["ZCTA20"] == median_df["Zip Code"])
    .withColumn(
        "Estimated Median Income", 
        regexp_replace(col("Estimated Median Income"), "[^0-9]", "")
    )
    .withColumn(
        "ZIP_Total_Income", 
        (col("Estimated Median Income") * col("Total_Housing"))
    )
    .groupBy("COMM")
    .agg(
        _sum("Total_POP").alias("Total_COMM_Pop"),
        _sum("ZIP_Total_Income").alias("COMM_Total_Income"),
        ST_Union_Aggr("geometry").alias("geometry")
    )
    .withColumn(
        "GDP_Per_Capita",
        (col("COMM_Total_Income")/col("Total_COMM_Pop"))
    )
    .select("COMM", "GDP_Per_Capita", "geometry") 
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#keep crime data only from 2020 and 2021. Also create a geometry column according to longtitude and latitude columns.
crime_data_20_21_df = (
    crime_df
    .filter(
        (substring(col("DATE OCC"), 1, 4) == "2020") |
        (substring(col("DATE OCC"), 1, 4) == "2021") 
    )
    .select("DATE OCC", "LAT", "LON")
    .withColumn("geom", ST_Point("LON", "LAT"))
    .drop("LAT", "LON")
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#final_top_3_df.show()

final_crimes_df = (
    joined
    .join(crime_data_20_21_df, ST_Within(crime_data_20_21_df.geom, joined.geometry), "inner")
    .groupBy("COMM")
    .agg(
        count("*").alias("#")
    )
)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
#join Cencus with crimes per COMM. Join key is Zip Code. Result is crimes per capita in every area.
crime_joined = (
    group_flattened
    .join(final_crimes_df, on="COMM", how="inner")
    .withColumn(
        "Crimes_Per_Capita",
        (col("#")/col("Total_Pop"))
    )
    .select("COMM", "Crimes_Per_Capita") #geometry 
)

top_10 = joined.orderBy(col("GDP_Per_Capita"), ascending=False).limit(10)

bottom_10 = joined.orderBy(col("GDP_Per_Capita"), ascending=True).limit(10)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
from pyspark.sql.functions import corr
import time

start = time.time()

#Corelation while using all areas
corr_joined = (
    joined
    .join(crime_joined, on="COMM", how="inner")
    .select("COMM", "GDP_Per_Capita", "Crimes_Per_Capita") 
)

full_corr = corr_joined.select(
    corr("GDP_Per_Capita", "Crimes_Per_Capita")
).collect()[0][0]

print("Correlation =", full_corr)

#Corelation while using top10 income areas
corr_top10 = (
    top_10
    .join(crime_joined, on="COMM", how="inner") # Broadcast Hash Join
    .select("COMM", "GDP_Per_Capita", "Crimes_Per_Capita") 
)

full_corr_top10 = corr_top10.select(
    corr("GDP_Per_Capita", "Crimes_Per_Capita")
).collect()[0][0]

print("Top 10 Correlation =", full_corr_top10)

#Corelation while using the bottom 10 areas
corr_bottom10 = (
    bottom_10
    .join(crime_joined, on="COMM", how="inner") # Broadcast Hash Join
    .select("COMM", "GDP_Per_Capita", "Crimes_Per_Capita") 
)

full_corr_bot10 = corr_bottom10.select(
    corr("GDP_Per_Capita", "Crimes_Per_Capita")
).collect()[0][0]

print("Bottom 10 Correlation =", full_corr_bot10)
end = time.time()
print("Execution time:", end - start, "seconds")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Correlation = 0.056990063545167884
# Top 10 Correlation = 0.2930302995361155
# Bottom 10 Correlation = 0.17968480714580115
# Execution time: 65.40431118011475 seconds

# %%
corr_joined.explain()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [COMM#124, GDP_Per_Capita#394, Crimes_Per_Capita#497]
#    +- SortMergeJoin [COMM#124], [COMM#522], Inner
#       :- Sort [COMM#124 ASC NULLS FIRST], false, 0
#       :  +- HashAggregate(keys=[COMM#124], functions=[sum(ZIP_Total_Income#350), sum(Total_POP#299L)], schema specialized)
#       :     +- Exchange hashpartitioning(COMM#124, 1000), ENSURE_REQUIREMENTS, [plan_id=5970]
#       :        +- HashAggregate(keys=[COMM#124], functions=[partial_sum(ZIP_Total_Income#350), partial_sum(Total_POP#299L)], schema specialized)
#       :           +- Project [COMM#124, Total_POP#299L, (cast(regexp_replace(Estimated Median Income#284, [^0-9], , 1) as double) * cast(Total_Housing#301L as double)) AS ZIP_Total_Income#350]
#       :              +- BroadcastHashJoin [cast(ZCTA20#144 as int)], [Zip Code#282], Inner, BuildRight, false
#       :                 :- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[sum(POP20#136L), sum(HOUSING20#134L)], schema specialized)
#       :                 :  +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=5962]
#       :                 :     +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#       :                 :        +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#       :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#       :                 :              +- Generate explode(features#99), false, [features#107]
#       :                 :                 +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#       :                 :                    +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#       :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=5965]
#       :                    +- Filter isnotnull(Zip Code#282)
#       :                       +- FileScan csv [Zip Code#282,Estimated Median Income#284] Batched: false, DataFilters: [isnotnull(Zip Code#282)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#       +- Sort [COMM#522 ASC NULLS FIRST], false, 0
#          +- Filter bloomfilter#1795 of [bf1795 COMM#124 estimatedNumRows=255300] filtering [COMM#522]
#             :  +- GenerateBloomFilter bf1795, 255300, 0, false, false, true, true, [id=#6104]
#             :     +- OutputAdapter [COMM#124, ZCTA20#144, sum#633L, sum#635L]
#             :        +- AdaptiveSparkPlan isFinalPlan=false
#             :           +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=6101]
#             :              +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#             :                 +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#             :                    +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#             :                       +- Generate explode(features#99), false, [features#107]
#             :                          +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#             :                             +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#             +- Project [COMM#522, (cast(##430L as double) / cast(Total_Pop#299L as double)) AS Crimes_Per_Capita#497]
#                +- BroadcastHashJoin [COMM#522], [COMM#445], Inner, BuildLeft, false
#                   :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=5992]
#                   :  +- HashAggregate(keys=[COMM#522, ZCTA20#542], functions=[sum(POP20#534L)], schema specialized)
#                   :     +- Exchange hashpartitioning(COMM#522, ZCTA20#542, 1000), ENSURE_REQUIREMENTS, [plan_id=5972]
#                   :        +- HashAggregate(keys=[COMM#522, ZCTA20#542], functions=[partial_sum(POP20#534L)], schema specialized)
#                   :           +- Project [features#107.properties.COMM AS COMM#522, features#107.properties.POP20 AS POP20#534L, features#107.properties.ZCTA20 AS ZCTA20#542]
#                   :              +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                   :                 +- Generate explode(features#508), false, [features#107]
#                   :                    +- Filter ((size(features#508, true) > 0) AND isnotnull(features#508))
#                   :                       +- FileScan geojson [features#508] Batched: false, DataFilters: [(size(features#508, true) > 0), isnotnull(features#508)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                   +- HashAggregate(keys=[COMM#445], functions=[count(1)], schema specialized)
#                      +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=5989]
#                         +- HashAggregate(keys=[COMM#445], functions=[partial_count(1)], schema specialized)
#                            +- Project [COMM#445]
#                               +- RangeJoin geometry#377: geometry, geom#407: geometry, CONTAINS
#                                  :- Filter isnotnull(geometry#377)
#                                  :  +- ObjectHashAggregate(keys=[COMM#445], functions=[st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@ad94c06, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :     +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=5982]
#                                  :        +- ObjectHashAggregate(keys=[COMM#445], functions=[partial_st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@ad94c06, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :           +- Project [COMM#445, geometry#306]
#                                  :              +- BroadcastHashJoin [cast(ZCTA20#465 as int)], [Zip Code#511], Inner, BuildRight, false
#                                  :                 :- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@61ef9d9c, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :                 :  +- Exchange hashpartitioning(COMM#445, ZCTA20#465, 1000), ENSURE_REQUIREMENTS, [plan_id=5974]
#                                  :                 :     +- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[partial_st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@61ef9d9c, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                                  :                 :        +- Project [features#107.properties.COMM AS COMM#445, features#107.properties.ZCTA20 AS ZCTA20#465, features#107.geometry AS geometry#110]
#                                  :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                                  :                 :              +- Generate explode(features#434), false, [features#107]
#                                  :                 :                 +- Filter ((size(features#434, true) > 0) AND isnotnull(features#434))
#                                  :                 :                    +- FileScan geojson [features#434] Batched: false, DataFilters: [(size(features#434, true) > 0), isnotnull(features#434)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                                  :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=5977]
#                                  :                    +- Filter isnotnull(Zip Code#511)
#                                  :                       +- FileScan csv [Zip Code#511] Batched: false, DataFilters: [isnotnull(Zip Code#511)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int>
#                                  +- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#407]
#                                     +- Filter (((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)) AND isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  ))
#                                        +- FileScan csv [DATE OCC#44,LAT#68,LON#69] Batched: false, DataFilters: [((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)), isnotnull( **o..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DATE OCC:string,LAT:double,LON:double>

# %%
corr_top10.explain()
corr_bottom10.explain()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [COMM#124, GDP_Per_Capita#394, Crimes_Per_Capita#497]
#    +- BroadcastHashJoin [COMM#124], [COMM#994], Inner, BuildLeft, false
#       :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6431]
#       :  +- TakeOrderedAndProject(limit=10, orderBy=[GDP_Per_Capita#394 DESC NULLS LAST], output=[COMM#124,GDP_Per_Capita#394])
#       :     +- HashAggregate(keys=[COMM#124], functions=[sum(ZIP_Total_Income#350), sum(Total_POP#299L)], schema specialized)
#       :        +- Exchange hashpartitioning(COMM#124, 1000), ENSURE_REQUIREMENTS, [plan_id=6404]
#       :           +- HashAggregate(keys=[COMM#124], functions=[partial_sum(ZIP_Total_Income#350), partial_sum(Total_POP#299L)], schema specialized)
#       :              +- Project [COMM#124, Total_POP#299L, (cast(regexp_replace(Estimated Median Income#284, [^0-9], , 1) as double) * cast(Total_Housing#301L as double)) AS ZIP_Total_Income#350]
#       :                 +- BroadcastHashJoin [cast(ZCTA20#144 as int)], [Zip Code#282], Inner, BuildRight, false
#       :                    :- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[sum(POP20#136L), sum(HOUSING20#134L)], schema specialized)
#       :                    :  +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=6396]
#       :                    :     +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#       :                    :        +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#       :                    :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#       :                    :              +- Generate explode(features#99), false, [features#107]
#       :                    :                 +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#       :                    :                    +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#       :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6399]
#       :                       +- Filter isnotnull(Zip Code#282)
#       :                          +- FileScan csv [Zip Code#282,Estimated Median Income#284] Batched: false, DataFilters: [isnotnull(Zip Code#282)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#       +- Project [COMM#994, (cast(##430L as double) / cast(Total_Pop#299L as double)) AS Crimes_Per_Capita#497]
#          +- BroadcastHashJoin [COMM#994], [COMM#445], Inner, BuildLeft, false
#             :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6427]
#             :  +- HashAggregate(keys=[COMM#994, ZCTA20#1014], functions=[sum(POP20#1006L)], schema specialized)
#             :     +- Exchange hashpartitioning(COMM#994, ZCTA20#1014, 1000), ENSURE_REQUIREMENTS, [plan_id=6407]
#             :        +- HashAggregate(keys=[COMM#994, ZCTA20#1014], functions=[partial_sum(POP20#1006L)], schema specialized)
#             :           +- Project [features#107.properties.COMM AS COMM#994, features#107.properties.POP20 AS POP20#1006L, features#107.properties.ZCTA20 AS ZCTA20#1014]
#             :              +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#             :                 +- Generate explode(features#980), false, [features#107]
#             :                    +- Filter ((size(features#980, true) > 0) AND isnotnull(features#980))
#             :                       +- FileScan geojson [features#980] Batched: false, DataFilters: [(size(features#980, true) > 0), isnotnull(features#980)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#             +- HashAggregate(keys=[COMM#445], functions=[count(1)], schema specialized)
#                +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6424]
#                   +- HashAggregate(keys=[COMM#445], functions=[partial_count(1)], schema specialized)
#                      +- Project [COMM#445]
#                         +- RangeJoin geometry#377: geometry, geom#407: geometry, CONTAINS
#                            :- Filter isnotnull(geometry#377)
#                            :  +- ObjectHashAggregate(keys=[COMM#445], functions=[st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@ad94c06, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :     +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6417]
#                            :        +- ObjectHashAggregate(keys=[COMM#445], functions=[partial_st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@ad94c06, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :           +- Project [COMM#445, geometry#306]
#                            :              +- BroadcastHashJoin [cast(ZCTA20#465 as int)], [Zip Code#983], Inner, BuildRight, false
#                            :                 :- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@61ef9d9c, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :  +- Exchange hashpartitioning(COMM#445, ZCTA20#465, 1000), ENSURE_REQUIREMENTS, [plan_id=6409]
#                            :                 :     +- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[partial_st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@61ef9d9c, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :        +- Project [features#107.properties.COMM AS COMM#445, features#107.properties.ZCTA20 AS ZCTA20#465, features#107.geometry AS geometry#110]
#                            :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                            :                 :              +- Generate explode(features#434), false, [features#107]
#                            :                 :                 +- Filter ((size(features#434, true) > 0) AND isnotnull(features#434))
#                            :                 :                    +- FileScan geojson [features#434] Batched: false, DataFilters: [(size(features#434, true) > 0), isnotnull(features#434)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                            :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6412]
#                            :                    +- Filter isnotnull(Zip Code#983)
#                            :                       +- FileScan csv [Zip Code#983] Batched: false, DataFilters: [isnotnull(Zip Code#983)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int>
#                            +- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#407]
#                               +- Filter (((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)) AND isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  ))
#                                  +- FileScan csv [DATE OCC#44,LAT#68,LON#69] Batched: false, DataFilters: [((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)), isnotnull( **o..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DATE OCC:string,LAT:double,LON:double>
#
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [COMM#124, GDP_Per_Capita#394, Crimes_Per_Capita#497]
#    +- BroadcastHashJoin [COMM#124], [COMM#1414], Inner, BuildLeft, false
#       :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6817]
#       :  +- TakeOrderedAndProject(limit=10, orderBy=[GDP_Per_Capita#394 ASC NULLS FIRST], output=[COMM#124,GDP_Per_Capita#394])
#       :     +- HashAggregate(keys=[COMM#124], functions=[sum(ZIP_Total_Income#350), sum(Total_POP#299L)], schema specialized)
#       :        +- Exchange hashpartitioning(COMM#124, 1000), ENSURE_REQUIREMENTS, [plan_id=6790]
#       :           +- HashAggregate(keys=[COMM#124], functions=[partial_sum(ZIP_Total_Income#350), partial_sum(Total_POP#299L)], schema specialized)
#       :              +- Project [COMM#124, Total_POP#299L, (cast(regexp_replace(Estimated Median Income#284, [^0-9], , 1) as double) * cast(Total_Housing#301L as double)) AS ZIP_Total_Income#350]
#       :                 +- BroadcastHashJoin [cast(ZCTA20#144 as int)], [Zip Code#282], Inner, BuildRight, false
#       :                    :- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[sum(POP20#136L), sum(HOUSING20#134L)], schema specialized)
#       :                    :  +- Exchange hashpartitioning(COMM#124, ZCTA20#144, 1000), ENSURE_REQUIREMENTS, [plan_id=6782]
#       :                    :     +- HashAggregate(keys=[COMM#124, ZCTA20#144], functions=[partial_sum(POP20#136L), partial_sum(HOUSING20#134L)], schema specialized)
#       :                    :        +- Project [features#107.properties.COMM AS COMM#124, features#107.properties.POP20 AS POP20#136L, features#107.properties.ZCTA20 AS ZCTA20#144, features#107.properties.HOUSING20 AS HOUSING20#134L]
#       :                    :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#       :                    :              +- Generate explode(features#99), false, [features#107]
#       :                    :                 +- Filter ((size(features#99, true) > 0) AND isnotnull(features#99))
#       :                    :                    +- FileScan geojson [features#99] Batched: false, DataFilters: [(size(features#99, true) > 0), isnotnull(features#99)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#       :                    +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6785]
#       :                       +- Filter isnotnull(Zip Code#282)
#       :                          +- FileScan csv [Zip Code#282,Estimated Median Income#284] Batched: false, DataFilters: [isnotnull(Zip Code#282)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int,Estimated Median Income:string>
#       +- Project [COMM#1414, (cast(##430L as double) / cast(Total_Pop#299L as double)) AS Crimes_Per_Capita#497]
#          +- BroadcastHashJoin [COMM#1414], [COMM#445], Inner, BuildLeft, false
#             :- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, true]),false), [plan_id=6813]
#             :  +- HashAggregate(keys=[COMM#1414, ZCTA20#1434], functions=[sum(POP20#1426L)], schema specialized)
#             :     +- Exchange hashpartitioning(COMM#1414, ZCTA20#1434, 1000), ENSURE_REQUIREMENTS, [plan_id=6793]
#             :        +- HashAggregate(keys=[COMM#1414, ZCTA20#1434], functions=[partial_sum(POP20#1426L)], schema specialized)
#             :           +- Project [features#107.properties.COMM AS COMM#1414, features#107.properties.POP20 AS POP20#1426L, features#107.properties.ZCTA20 AS ZCTA20#1434]
#             :              +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#             :                 +- Generate explode(features#1400), false, [features#107]
#             :                    +- Filter ((size(features#1400, true) > 0) AND isnotnull(features#1400))
#             :                       +- FileScan geojson [features#1400] Batched: false, DataFilters: [(size(features#1400, true) > 0), isnotnull(features#1400)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#             +- HashAggregate(keys=[COMM#445], functions=[count(1)], schema specialized)
#                +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6810]
#                   +- HashAggregate(keys=[COMM#445], functions=[partial_count(1)], schema specialized)
#                      +- Project [COMM#445]
#                         +- RangeJoin geometry#377: geometry, geom#407: geometry, CONTAINS
#                            :- Filter isnotnull(geometry#377)
#                            :  +- ObjectHashAggregate(keys=[COMM#445], functions=[st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@ad94c06, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :     +- Exchange hashpartitioning(COMM#445, 1000), ENSURE_REQUIREMENTS, [plan_id=6803]
#                            :        +- ObjectHashAggregate(keys=[COMM#445], functions=[partial_st_union_aggr(geometry#306, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@ad94c06, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :           +- Project [COMM#445, geometry#306]
#                            :              +- BroadcastHashJoin [cast(ZCTA20#465 as int)], [Zip Code#1403], Inner, BuildRight, false
#                            :                 :- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@61ef9d9c, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :  +- Exchange hashpartitioning(COMM#445, ZCTA20#465, 1000), ENSURE_REQUIREMENTS, [plan_id=6795]
#                            :                 :     +- ObjectHashAggregate(keys=[COMM#445, ZCTA20#465], functions=[partial_st_union_aggr(geometry#110, org.apache.spark.sql.sedona_sql.expressions.ST_Union_Aggr@61ef9d9c, class[value[0]: geometry], class[value[0]: array<geometry>], true, true, 0, 0, None)])
#                            :                 :        +- Project [features#107.properties.COMM AS COMM#445, features#107.properties.ZCTA20 AS ZCTA20#465, features#107.geometry AS geometry#110]
#                            :                 :           +- Filter ((((isnotnull(features#107.properties.ZCTA20) AND isnotnull(features#107.properties.HOUSING20)) AND isnotnull(features#107.properties.POP20)) AND isnotnull(features#107.properties.COMM)) AND ((((cast(features#107.properties.ZCTA20 as int) > 0) AND (features#107.properties.HOUSING20 > 0)) AND (features#107.properties.POP20 > 0)) AND NOT (features#107.properties.COMM = )))
#                            :                 :              +- Generate explode(features#434), false, [features#107]
#                            :                 :                 +- Filter ((size(features#434, true) > 0) AND isnotnull(features#434))
#                            :                 :                    +- FileScan geojson [features#434] Batched: false, DataFilters: [(size(features#434, true) > 0), isnotnull(features#434)], Format: GEOJSON, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [IsNotNull(features)], ReadSchema: struct<features:array<struct<geometry:binary,properties:struct<BG20:string,BG20FIP_CURRENT:string...
#                            :                 +- BroadcastExchange HashedRelationBroadcastMode(List(cast(input[0, int, false] as bigint)),false), [plan_id=6798]
#                            :                    +- Filter isnotnull(Zip Code#1403)
#                            :                       +- FileScan csv [Zip Code#1403] Batched: false, DataFilters: [isnotnull(Zip Code#1403)], Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_i..., PartitionFilters: [], PushedFilters: [IsNotNull(Zip Code)], ReadSchema: struct<Zip Code:int>
#                            +- Project [ **org.apache.spark.sql.sedona_sql.expressions.ST_Point**   AS geom#407]
#                               +- Filter (((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)) AND isnotnull( **org.apache.spark.sql.sedona_sql.expressions.ST_Point**  ))
#                                  +- FileScan csv [DATE OCC#44,LAT#68,LON#69] Batched: false, DataFilters: [((substring(DATE OCC#44, 1, 4) = 2020) OR (substring(DATE OCC#44, 1, 4) = 2021)), isnotnull( **o..., Format: CSV, Location: InMemoryFileIndex(1 paths)[s3://initial-notebook-data-bucket-dblab-905418150721/project_data/LA_C..., PartitionFilters: [], PushedFilters: [], ReadSchema: struct<DATE OCC:string,LAT:double,LON:double>
